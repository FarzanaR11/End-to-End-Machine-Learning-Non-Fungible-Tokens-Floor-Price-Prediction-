# %% [markdown]
# #Connect from Colab Python platform using mount drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Importing Libraries

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
path ="/content/drive/MyDrive/NFT_Top_Collections.csv"
df = pd.read_csv(path)

#dataset is now stored in a Pandas Dataframe

df.describe
# Out:
# <bound method NDFrame.describe of      Index                               Name    Volume    Volume_USD  \
# 0        0                      basis.markets  27256.63  4.001818e+06
# 1        1               Skeleton Crew Skulls  11381.25  1.670995e+06
# 2        2                           Flippies   6732.19  9.884201e+05
# 3        3  Meerkat Millionaires Country Club   3734.76  5.483375e+05
# 4        4                      Stylish Studs   3191.15  4.685246e+05
# ..     ...                                ...       ...           ...
# 587    595                NEO MONKEY BUSINESS      0.00  0.000000e+00
# 588    596                          Cops Game      0.00  0.000000e+00
# 589    597                   Floppa Syndicate      0.00  0.000000e+00
# 590    598                           Duck BRO      0.00  0.000000e+00
# 591    599                         CryptoPets      0.00  0.000000e+00
#
#       Market_Cap  Market_Cap_USD  Sales  Floor_Price  Floor_Price_USD  \
# ...

# %% [markdown]
# # 1. Data insight (using df.info)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              592 non-null    int64
#  1   Name               592 non-null    object
#  2   Volume             592 non-null    float64
#  3   Volume_USD         592 non-null    float64
#  4   Market_Cap         592 non-null    float64
#  5   Market_Cap_USD     592 non-null    float64
#  6   Sales              592 non-null    int64
#  7   Floor_Price        544 non-null    float64
#  8   Floor_Price_USD    544 non-null    float64
#  9   Average_Price      592 non-null    float64
#  10  Average_Price_USD  592 non-null    float64
#  11  Owners             592 non-null    int64
#  12  Assets             592 non-null    int64
#  13  Owner_Asset_Ratio  543 non-null    float64
#  14  Category           310 non-null    object
#  15  Website            481 non-null    object
# ...

# %%
#Load the dataset
dataset = pd.read_csv("/content/drive/MyDrive/NFT_Top_Collections.csv")

# %%
#Separate numeric and categorical variables
numeric_data = dataset.select_dtypes(include=[np.number])
categorical_data = dataset.select_dtypes(exclude=[np.number])

numeric_data.shape
categorical_data.shape
# Out:
# (592, 4)

# %% [markdown]
# #2. Individual Histogram for the numerical features

# %%
df=pd.read_csv("/content/drive/MyDrive/NFT_Top_Collections.csv")

# %%
df.head(n=592)

# %%
df.columns
# Out:
# Index(['Index', 'Name', 'Volume', 'Volume_USD', 'Market_Cap', 'Market_Cap_USD',
#        'Sales', 'Floor_Price', 'Floor_Price_USD', 'Average_Price',
#        'Average_Price_USD', 'Owners', 'Assets', 'Owner_Asset_Ratio',
#        'Category', 'Website', 'Logo'],
#       dtype='object')

# %%
x=df.Index 
y=df.Floor_Price_USD
plt.hist([x,y])
plt.xlabel('Index')
plt.ylabel('Floor_Price_USD')
plt.title('Index vs Floor_Price_USD')
# Out:
# Text(0.5, 1.0, 'Index vs Floor_Price_USD')

# %%
x=df.Name
y=df.Floor_Price_USD
plt.hist([x,y])
plt.xlabel('Name')
plt.ylabel('Floor_Price_USD')
plt.title('Name vs Floor_Price_USD')
# Out:
# Text(0.5, 1.0, 'Name vs Floor_Price_USD')

# %%
x=df.Volume
y=df.Floor_Price_USD
plt.hist([x,y])
plt.xlabel('Volume')
plt.ylabel('Floor_Price_USD')
plt.title('Volume vs Floor_Price_USD')
# Out:
# Text(0.5, 1.0, 'Volume vs Floor_Price_USD')

# %%
x=df.Volume_USD
y=df.Floor_Price_USD
plt.hist([x,y])
plt.xlabel('Volume_USD')
plt.ylabel('Floor_Price_USD')
plt.title('Volume_USD vs Floor_Price_USD')
# Out:
# Text(0.5, 1.0, 'Volume_USD vs Floor_Price_USD')

# %%
x=df.Market_Cap
y=df.Floor_Price_USD
plt.hist([x,y])
plt.xlabel('Market_Cap')
plt.ylabel('Floor_Price_USD')
plt.title('Market_Cap vs Floor_Price_USD')
# Out:
# Text(0.5, 1.0, 'Market_Cap vs Floor_Price_USD')

# %%
x=df.Market_Cap_USD
y=df.Floor_Price_USD
plt.hist([x,y])
plt.xlabel('Market_Cap_USD')
plt.ylabel('Floor_Price_USD')
plt.title('Market_Cap_USD vs Floor_Price_USD')
# Out:
# Text(0.5, 1.0, 'Market_Cap_USD vs Floor_Price_USD')

# %%
x=df.Sales
y=df.Floor_Price_USD
plt.hist([x,y])
plt.xlabel('Sales')
plt.ylabel('Floor_Price_USD')
plt.title('Sales vs Floor_Price_USD')
# Out:
# Text(0.5, 1.0, 'Sales vs Floor_Price_USD')

# %%
x=df.Floor_Price
y=df.Floor_Price_USD
plt.hist([x,y])
plt.xlabel('Floor_Price')
plt.ylabel('Floor_Price_USD')
plt.title('Floor_Price vs Floor_Price_USD')
# Out:
# Text(0.5, 1.0, 'Floor_Price vs Floor_Price_USD')

# %%
x=df.Floor_Price_USD
y=df.Floor_Price_USD
plt.hist([x,y])
plt.xlabel('Floor_Price_USD')
plt.ylabel('Floor_Price_USD')
plt.title('Floor_Price_USD vs Floor_Price_USD')
# Out:
# Text(0.5, 1.0, 'Floor_Price_USD vs Floor_Price_USD')

# %%
x=df.Average_Price
y=df.Floor_Price_USD
plt.hist([x,y])
plt.xlabel('Average_Price')
plt.ylabel('Floor_Price_USD')
plt.title('Average_Price vs Floor_Price_USD')
# Out:
# Text(0.5, 1.0, 'Average_Price vs Floor_Price_USD')

# %%
x=df.Average_Price_USD
y=df.Floor_Price_USD
plt.hist([x,y])
plt.xlabel('Average_Price_USD')
plt.ylabel('Floor_Price_USD')
plt.title('Average_Price_USD vs Floor_Price_USD')
# Out:
# Text(0.5, 1.0, 'Average_Price_USD vs Floor_Price_USD')

# %%
x=df.Owners 
y=df.Floor_Price_USD
plt.hist([x,y])
plt.xlabel('Owners ')
plt.ylabel('Floor_Price_USD')
plt.title('Owners vs Floor_Price_USD')
# Out:
# Text(0.5, 1.0, 'Owners vs Floor_Price_USD')

# %%
x=df.Assets
y=df.Floor_Price_USD
plt.hist([x,y])
plt.xlabel('Assets')
plt.ylabel('Floor_Price_USD')
plt.title('Assets vs Floor_Price_USD')
# Out:
# Text(0.5, 1.0, 'Assets vs Floor_Price_USD')

# %%
x=df.Owner_Asset_Ratio
y=df.Floor_Price_USD
plt.hist([x,y])
plt.xlabel('Owner_Asset_Ratio')
plt.ylabel('Floor_Price_USD')
plt.title('Owner_Asset_Ratio vs Floor_Price_USD')
# Out:
# Text(0.5, 1.0, 'Owner_Asset_Ratio vs Floor_Price_USD')

# %%
x= (df['Category']).astype(str)
y=df.Floor_Price_USD
plt.hist([x,y])
plt.xlabel('Category')
plt.ylabel('Floor_Price_USD')
plt.title('Category vs Floor_Price_USD')
# Out:
# Text(0.5, 1.0, 'Category vs Floor_Price_USD')

# %%
x=(df['Logo']).astype(str)
y=df.Floor_Price_USD
plt.hist([x,y])
plt.xlabel('Logo')
plt.ylabel('Floor_Price_USD')
plt.title('Logo vs Floor_Price_USD')
# Out:
# Text(0.5, 1.0, 'Logo vs Floor_Price_USD')

# %% [markdown]
# # 5. Categorical vs Numerical ( with different colors )

# %%
import seaborn as sns
sns.swarmplot(x="Name", y="Sales", data=df)

# %% [markdown]
# # 6.  Numerical vs Numerical pairplot

# %%
import seaborn as sns
sns.pairplot(df, hue="Owner_Asset_Ratio")

# %% [markdown]
# # 7. Missing data handling

# %%
import pandas as pd

print("Number of null values: ")
print(df.isnull().sum())
# Out:
# Number of null values:
# Index                  0
# Name                   0
# Volume                 0
# Volume_USD             0
# Market_Cap             0
# Market_Cap_USD         0
# Sales                  0
# Floor_Price           48
# Floor_Price_USD       48
# Average_Price          0
# Average_Price_USD      0
# Owners                 0
# Assets                 0
# Owner_Asset_Ratio     49
# Category             282
# Website              111
# Logo                   1
# dtype: int64

# %%
df['Floor_Price_USD'].fillna(df['Floor_Price_USD'].mean(), inplace=True)

# %%
import pandas as pd

print("Number of null values: ")
print(df.isnull().sum())
# Out:
# Number of null values:
# Index                  0
# Name                   0
# Volume                 0
# Volume_USD             0
# Market_Cap             0
# Market_Cap_USD         0
# Sales                  0
# Floor_Price           48
# Floor_Price_USD        0
# Average_Price          0
# Average_Price_USD      0
# Owners                 0
# Assets                 0
# Owner_Asset_Ratio     49
# Category             282
# Website              111
# Logo                   1
# dtype: int64

# %%
df.drop(['Category'], axis=1)
# Out:
#      Index                               Name    Volume    Volume_USD  \
# 0        0                      basis.markets  27256.63  4.001818e+06
# 1        1               Skeleton Crew Skulls  11381.25  1.670995e+06
# 2        2                           Flippies   6732.19  9.884201e+05
# 3        3  Meerkat Millionaires Country Club   3734.76  5.483375e+05
# 4        4                      Stylish Studs   3191.15  4.685246e+05
# ..     ...                                ...       ...           ...
# 587    595                NEO MONKEY BUSINESS      0.00  0.000000e+00
# 588    596                          Cops Game      0.00  0.000000e+00
# 589    597                   Floppa Syndicate      0.00  0.000000e+00
# 590    598                           Duck BRO      0.00  0.000000e+00
# 591    599                         CryptoPets      0.00  0.000000e+00
#
#       Market_Cap  Market_Cap_USD  Sales  Floor_Price  Floor_Price_USD  \
# ...

# %%
import pandas as pd

print("Number of null values: ")
print(df.isnull().sum())
# Out:
# Number of null values:
# Index                  0
# Name                   0
# Volume                 0
# Volume_USD             0
# Market_Cap             0
# Market_Cap_USD         0
# Sales                  0
# Floor_Price           48
# Floor_Price_USD        0
# Average_Price          0
# Average_Price_USD      0
# Owners                 0
# Assets                 0
# Owner_Asset_Ratio     49
# Category             282
# Website              111
# Logo                   1
# dtype: int64

# %% [markdown]
# # 8. Stratified sampling on output feature

# %%
# importing the dataset
import pandas as pd
import matplotlib.pyplot as plt

# looking at the dataset
print(df.head())
print(df.info())
print(df.Sales.value_counts())
print(df.describe())

# spliting the data into training and test
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(df, test_size=0.2, random_state=42)

# visualizing the histogram 
import numpy as np
df['Floor_Price_USD'] = pd.cut(df['Floor_Price_USD'], bins=[0., 1.5, 3.0, 4.5, 6., np.inf], labels=[1, 2, 3, 4, 5])
# Out:
#    Index                               Name    Volume    Volume_USD  \
# 0      0                      basis.markets  27256.63  4.001818e+06
# 1      1               Skeleton Crew Skulls  11381.25  1.670995e+06
# 2      2                           Flippies   6732.19  9.884201e+05
# 3      3  Meerkat Millionaires Country Club   3734.76  5.483375e+05
# 4      4                      Stylish Studs   3191.15  4.685246e+05
#
#     Market_Cap  Market_Cap_USD Sales  Floor_Price  Floor_Price_USD  \
# 0   708.145455    103969.91560     5        39.50        5799.3900
# 1   106.656000     15659.23392     5         0.67          98.3694
# 2  1663.863158    244288.38880     5         0.80         117.4560
# 3    90.275000     13254.17550     5         3.79         556.4478
# 4   165.000000     24225.30000     5         4.30         631.3260
#
#    Average_Price  Average_Price_USD  Owners  Assets  Owner_Asset_Ratio  \
# 0      74.471667       10933.930100      12      16              75.00
# ...

# %%
# stratified sampling
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_index, test_index in split.split(df, df["Floor_Price_USD"]):
    strat_train_set = df.loc[train_index]
    strat_test_set = df.loc[test_index]
    
strat_test_set['Floor_Price_USD'].value_counts() / len(strat_test_set)
# Out:
# 5    0.924370
# 3    0.033613
# 4    0.025210
# 2    0.016807
# 1    0.000000
# Name: Floor_Price_USD, dtype: float64

# %% [markdown]
# # 9. One hot encoding for categorical features

# %%
#importing libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
one_hot_encoded_data = pd.get_dummies(df, columns = ['Name','Website'])
print(one_hot_encoded_data)
# Out:
#      Index    Volume    Volume_USD   Market_Cap  Market_Cap_USD Sales  \
# 0        0  27256.63  4.001818e+06   708.145455    103969.91560     5
# 1        1  11381.25  1.670995e+06   106.656000     15659.23392     5
# 2        2   6732.19  9.884201e+05  1663.863158    244288.38880     5
# 3        3   3734.76  5.483375e+05    90.275000     13254.17550     5
# 4        4   3191.15  4.685246e+05   165.000000     24225.30000     5
# ..     ...       ...           ...          ...             ...   ...
# 587    595      0.00  0.000000e+00     0.000000         0.00000   NaN
# 588    596      0.00  0.000000e+00     0.000000         0.00000   NaN
# 589    597      0.00  0.000000e+00     0.000000         0.00000   NaN
# 590    598      0.00  0.000000e+00     0.000000         0.00000   NaN
# 591    599      0.00  0.000000e+00     0.000000         0.00000   NaN
#
#      Floor_Price  Floor_Price_USD  Average_Price  Average_Price_USD  ...  \
# ...

# %% [markdown]
# # 10. Normalization / Standardization for numerical

# %%
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()
df[['Index', 'Market_Cap', 'Market_Cap_USD', 'Floor_Price_USD']] = mms.fit_transform(df[['Index', 'Market_Cap', 'Market_Cap_USD', 'Floor_Price_USD']])
df
# Out:
#         Index                               Name    Volume    Volume_USD  \
# 0    0.000000                      basis.markets  27256.63  4.001818e+06
# 1    0.001669               Skeleton Crew Skulls  11381.25  1.670995e+06
# 2    0.003339                           Flippies   6732.19  9.884201e+05
# 3    0.005008  Meerkat Millionaires Country Club   3734.76  5.483375e+05
# 4    0.006678                      Stylish Studs   3191.15  4.685246e+05
# ..        ...                                ...       ...           ...
# 587  0.993322                NEO MONKEY BUSINESS      0.00  0.000000e+00
# 588  0.994992                          Cops Game      0.00  0.000000e+00
# 589  0.996661                   Floppa Syndicate      0.00  0.000000e+00
# 590  0.998331                           Duck BRO      0.00  0.000000e+00
# 591  1.000000                         CryptoPets      0.00  0.000000e+00
#
#      Market_Cap  Market_Cap_USD  Sales  Floor_Price  Floor_Price_USD  \
# ...

# %% [markdown]
# # 11. Correlation matrix

# %%
corr = df.corr()

corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_db73b_row0_col0, #T_db73b_row1_col1, #T_db73b_row1_col2, #T_db73b_row2_col1, #T_db73b_row2_col2, #T_db73b_row3_col3, #T_db73b_row3_col4, #T_db73b_row4_col3, #T_db73b_row4_col4, #T_db73b_row5_col5, #T_db73b_row5_col6, #T_db73b_row6_col5, #T_db73b_row6_col6, #T_db73b_row7_col7, #T_db73b_row7_col8, #T_db73b_row8_col7, #T_db73b_row8_col8, #T_db73b_row9_col9, #T_db73b_row10_col10, #T_db73b_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_db73b_row0_col1, #T_db73b_row0_col2, #T_db73b_row0_col3, #T_db73b_row0_col4, #T_db73b_row0_col7, #T_db73b_row0_col8, #T_db73b_row0_col9, #T_db73b_row0_col10, #T_db73b_row0_col11, #T_db73b_row3_col0, #T_db73b_row4_col0, #T_db73b_row10_col5, #T_db73b_row10_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_db73b_row0_col5, #T_db73b_row0_col6 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_db73b_row1_col0, #T_db73b_row2_col0 {
#   background-color: #4e68d8;
# ...

# %% [markdown]
# # 12. Dropping any feature if they seem extremely uncorrelated

# %%
import numpy as np
import pandas as pd
import sklearn as sklearn
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import seaborn as sns


print(df.describe())

#filtering the df to improve results
df = df[(df['Owners'] > 5) & (df['Assets'] < 99)]

print(df.describe())


maxVal = 1
df.unsafe = df['unsafe'].where(df['unsafe'] <= maxVal, maxVal)

df.drop(df.columns[0], axis=1, inplace=True)
df.drop(df.columns[-2], axis=1, inplace=True)

#setting features and labels
labels = np.array(df['unsafe'])
features= df.drop('unsafe', axis = 1)

# Saving feature names for later use
feature_list = list(features.columns)

# Convert to numpy array
features = np.array(features)

from sklearn.model_selection import train_test_split

# 30% examples in test data
train, test, train_labels, test_labels = train_test_split(features, labels,
                                                          stratify = labels,
                                                          test_size = 0.4,
                                                          random_state = 12)

from sklearn.ensemble import RandomForestClassifier

# Create the model with 100 trees
model = RandomForestClassifier(n_estimators=100,
                               random_state=12,
                               max_features = 'sqrt',
                               n_jobs=-1, verbose = 1, class_weight={0:1, 1:1})

# Fit on training data
model.fit(train, train_labels)
predictions = model.predict(test)


print(np.mean(predictions))
print(predictions.shape)


from sklearn.metrics import classification_report
print(classification_report(test_labels, predictions)
# Out:
#   File "<ipython-input-37-831fb2e31192>", line 59
#     print(classification_report(test_labels, predictions)
#                                                          ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# # 13. Data balancing(bonus)

# %%
#Import required sampling libraries
from sklearn.utils import resample

# %%
#Define the majority and minority class

df_minority9 = df[df['Name']=='c9']
df_majority1 = df[df['Index']=='c1']
df_majority2 = df[df['Sales']=='c2']
df_majority3 = df[df['Logo']=='c3']
df_majority4 = df[df['Volume_USD']=='c4']
df_majority5 = df[df['Volume']=='c5']
df_majority6 = df[df['Average_Price']=='c6']
df_majority7 = df[df['Average_Price_USD']=='c7']
df_majority8 = df[df['Owner_Asset_Ratio']=='c8']

#Unndersample majority class
maj_class1 = resample(df_majority1, 
                                 replace=True,     
                                 n_samples=1324,    
                                 random_state=123) 
maj_class2 = resample(df_majority2, 
                                 replace=True,     
                                 n_samples=1324,    
                                 random_state=123) 
maj_class3 = resample(df_majority3, 
                                 replace=True,     
                                 n_samples=1324,    
                                 random_state=123) 
maj_class4 = resample(df_majority4, 
                                 replace=True,     
                                 n_samples=1324,    
                                 random_state=123) 
maj_class5 = resample(df_majority5, 
                                 replace=True,     
                                 n_samples=1324,    
                                 random_state=123) 
maj_class6 = resample(df_majority6, 
                                 replace=True,     
                                 n_samples=1324,    
                                 random_state=123) 
maj_class7 = resample(df_majority7, 
                                 replace=True,     
                                 n_samples=1324,    
maj_class8 = resample(df_majority8, 
                                 replace=True,     
                                 n_samples=1324,    
                                 random_state=123)

# %%
#Combine minority class with undersampled majority class
df=pd.concat([df_minority9,maj_class1,maj_class2,maj_class3,maj_class4, maj_class5,dmaj_class6,maj_class7,maj_class8])

# %%
#Display new balanced class counts
df['class'].value_counts()
